# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
Hayat
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
Hayat.describe()
# Out:
#        Age (years)-Float/Int  Your Weight in kg? (float)  \
# count             375.000000                  375.000000
# mean               27.576933                   69.321147
# std                 7.224460                   16.264434
# min                 0.000000                    7.000000
# 25%                24.000000                   58.050000
# 50%                27.000000                   68.300000
# 75%                31.000000                   78.500000
# max                90.000000                  161.000000
#
#        Height in cm? Freelancer- (Float)  \
# count                         375.000000
# mean                          162.679282
# std                           172.246844
# min                             0.000000
# 25%                           158.000000
# 50%                           169.000000
# 75%                           175.225000
# max                          1661.160000
#
#        How many hours you code a day? (int) e.g: 5,4,3  \
# ...

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Hayat)
plt.show()

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="How many hours you code a day? (int) e.g: 5,4,3", y = "Light kitni der band hti hy? int",data=Hayat)
plt.show()

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
plt.figure(figsize = (9,5))

sns.barplot(x="Gender", y="Light kitni der band hti hy? int", data=Hayat)
plt.show()

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
plt.figure(figsize = (15,5))
sns.barplot(x="Location", y = "Light kitni der band hti hy? int", data=Hayat)

plt.show()

# %%
#### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
plt.figure(figsize = (15,5))
sns.barplot(x="Gender", y = "Light kitni der band hti hy? int", data=Hayat)

plt.show()

# %%
### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="Are you Vaccinated?",y = "Light kitni der band hti hy? int",order = ["No","Yes"],color="grey",palette="colorblind", data=Hayat) 
plt.show()

# %%
### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="Are you Vaccinated?",y = "Light kitni der band hti hy? int",order = ["No","Yes"],estimator=mean,color="grey",palette="colorblind", data=Hayat) 
plt.show()

# %%
### import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="Light kitni der band hti hy? int",y ="Are you Vaccinated?",order = ["No","Yes"],estimator=mean,color="grey",palette="colorblind", data=Hayat) 
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
sns.barplot(x="Light kitni der band hti hy? int",y ="Are you Vaccinated?",order = ["No","Yes"],estimator=mean,color="grey",palette="colorblind", data=Hayat,facecolor=(0.9,0.4,0.4,0.4),
 errcolor="0.9", edgecolor="0.3") 
plt.show()
