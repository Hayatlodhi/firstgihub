# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ha=pd.read_csv("Chilla_data2_for_plots.csv")
Ha
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ht=pd.read_csv("chilla_data2_for_plots.csv")
Ht.describe()
# Out:
#        Age (years)-Float/Int  Your Weight in kg? (float)  \
# count             375.000000                  375.000000
# mean               27.576933                   69.321147
# std                 7.224460                   16.264434
# min                 0.000000                    7.000000
# 25%                24.000000                   58.050000
# 50%                27.000000                   68.300000
# 75%                31.000000                   78.500000
# max                90.000000                  161.000000
#
#        Height in cm? Freelancer- (Float)  \
# count                         375.000000
# mean                          162.679282
# std                           172.246844
# min                             0.000000
# 25%                           158.000000
# 50%                           169.000000
# 75%                           175.225000
# max                          1661.160000
#
#        How many hours you code a day? (int) e.g: 5,4,3  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ht=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Gender", y = "Your Weight in kg? (float)", data=Ht)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ht=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y ="Age (years)-Float/Int",data=Ht)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ht=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)
plt.title("Hayat Lineplot for Chilla data")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Ht=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)
plt.title("Hayat Lineplot for Chilla data")
plt.xlim(3)
plt.ylim(20)
plt.show()

# %% [markdown]
# **Set styles**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hanif=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)
sns.set_style("whitegrid")
plt.title("Hayat Lineplot for Chilla data")
plt.xlim(-3)
plt.ylim(10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hanif=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)
sns.set_style("darkgrid")
plt.title("Hayat Lineplot for Chilla data")
plt.xlim(-3)
plt.ylim(10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hanif=pd.read_csv("Chilla_data2_for_plots.csv")
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)
sns.set_style("dark")
plt.title("Hayat Lineplot for Chilla data")
plt.xlim(-3)
plt.ylim(10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
Hayat=pd.read_csv("Chilla_data2_for_plots.csv")
plt.figure(figsize = (4,9))
sns.lineplot(x="Research/Working experience (Float/Int) years", y = "Age (years)-Float/Int",data=Ht)

plt.title("Hayat Lineplot for Chilla data")
sns.set_style(style=None, rc = None)
sns.set_style("ticks")

plt.xlim(-3)
plt.ylim(10)
plt.show()
